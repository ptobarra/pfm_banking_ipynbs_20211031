# %%
# Load data using read_excel
from pandas import read_csv, read_excel, date_range, RangeIndex, DataFrame, to_datetime
from datetime import datetime
from matplotlib import pyplot
transacciones_nomina_df = read_excel('20210513 mmelero (249236).xlsx', sheet_name='Hoja1')
transacciones_nomina_df
# Out:
#      Fecha transacción  Importe  ID Categoría           Nombre categoría  \
# 0           2020-07-24    -1.20          84.0                 parking_84
# 1           2020-07-23    -4.50         117.0  regalos_celebraciones_117
# 2           2020-07-23   -13.53          70.0           supermercados_70
# 3           2020-07-22   -51.40         222.0                   adsl_222
# 4           2020-07-22   -11.00          70.0           supermercados_70
# ...                ...      ...           ...                        ...
# 1482        2016-09-05  1533.02          18.0     retribucion_liquida_18
# 1483        2016-09-05  -617.47         126.0    liquidacion_tarjeta_126
# 1484        2016-09-05  -138.08         125.0                 cuotas_125
# 1485        2016-09-01   -32.22          90.0            seguro_salud_90
# 1486        2016-09-01   -33.00         434.0                 cuotas_434
#
#       Nivel categoría  iD categoría padre Nombre categoría padre  \
# ...

# %%
# nos quedamos con transacciones desde 'Fecha transacción' hasta 'ID Categoría'

# %%
transacciones_nomina_df=transacciones_nomina_df.iloc[:,0:3]
transacciones_nomina_df
# Out:
#      Fecha transacción  Importe  ID Categoría
# 0           2020-07-24    -1.20          84.0
# 1           2020-07-23    -4.50         117.0
# 2           2020-07-23   -13.53          70.0
# 3           2020-07-22   -51.40         222.0
# 4           2020-07-22   -11.00          70.0
# ...                ...      ...           ...
# 1482        2016-09-05  1533.02          18.0
# 1483        2016-09-05  -617.47         126.0
# 1484        2016-09-05  -138.08         125.0
# 1485        2016-09-01   -32.22          90.0
# 1486        2016-09-01   -33.00         434.0
#
# [1487 rows x 3 columns]

# %%
# nos quedamos con las transacciones de categoria 18

# %%
transacciones_nomina_df=transacciones_nomina_df[transacciones_nomina_df['ID Categoría'] == 18.0]
transacciones_nomina_df
# Out:
#      Fecha transacción  Importe  ID Categoría
# 16          2020-07-15  1888.97          18.0
# 33          2020-07-06  2031.55          18.0
# 55          2020-06-18    15.62          18.0
# 127         2020-05-05  2004.95          18.0
# 134         2019-12-20  1758.22          18.0
# 144         2019-12-06   555.77          18.0
# 148         2019-12-04  1600.00          18.0
# 164         2019-11-06  1675.77          18.0
# 181         2019-10-02  1675.77          18.0
# 227         2019-06-04  1675.77          18.0
# 275         2019-05-03  3456.76          18.0
# 306         2019-04-09  1500.00          18.0
# 310         2019-04-03  1675.77          18.0
# 333         2019-03-04  1675.77          18.0
# 367         2019-02-05   783.99          18.0
# 370         2019-02-04  1675.77          18.0
# 431         2018-12-21  1882.53          18.0
# 437         2018-12-04  1789.39          18.0
# 487         2018-11-02  2382.94          18.0
# ...

# %%
# borramos la columna de 'ID Categoría'

# %%
transacciones_nomina_df=transacciones_nomina_df.drop(['ID Categoría'], axis=1)
transacciones_nomina_df
# Out:
#      Fecha transacción  Importe
# 16          2020-07-15  1888.97
# 33          2020-07-06  2031.55
# 55          2020-06-18    15.62
# 127         2020-05-05  2004.95
# 134         2019-12-20  1758.22
# 144         2019-12-06   555.77
# 148         2019-12-04  1600.00
# 164         2019-11-06  1675.77
# 181         2019-10-02  1675.77
# 227         2019-06-04  1675.77
# 275         2019-05-03  3456.76
# 306         2019-04-09  1500.00
# 310         2019-04-03  1675.77
# 333         2019-03-04  1675.77
# 367         2019-02-05   783.99
# 370         2019-02-04  1675.77
# 431         2018-12-21  1882.53
# 437         2018-12-04  1789.39
# 487         2018-11-02  2382.94
# 517         2018-10-02  2515.38
# 542         2018-09-03  1789.39
# 605         2018-08-01  1789.39
# 628         2018-07-26  1882.53
# 642         2018-07-03  1789.39
# 697         2018-06-01  1799.26
# 744         2018-05-04  1799.26
# 798         2018-04-04  1799.26
# 856         2018-03-05  3964.43
# ...

# %%
# nos quedamos con las transacciones mayores o iguales a 950 eur

# %%
transacciones_nomina_df=transacciones_nomina_df[transacciones_nomina_df['Importe'] >= 950.0]
transacciones_nomina_df
# Out:
#      Fecha transacción  Importe
# 16          2020-07-15  1888.97
# 33          2020-07-06  2031.55
# 127         2020-05-05  2004.95
# 134         2019-12-20  1758.22
# 148         2019-12-04  1600.00
# 164         2019-11-06  1675.77
# 181         2019-10-02  1675.77
# 227         2019-06-04  1675.77
# 275         2019-05-03  3456.76
# 306         2019-04-09  1500.00
# 310         2019-04-03  1675.77
# 333         2019-03-04  1675.77
# 370         2019-02-04  1675.77
# 431         2018-12-21  1882.53
# 437         2018-12-04  1789.39
# 487         2018-11-02  2382.94
# 517         2018-10-02  2515.38
# 542         2018-09-03  1789.39
# 605         2018-08-01  1789.39
# 628         2018-07-26  1882.53
# 642         2018-07-03  1789.39
# 697         2018-06-01  1799.26
# 744         2018-05-04  1799.26
# 798         2018-04-04  1799.26
# 856         2018-03-05  3964.43
# 906         2018-02-01  2451.77
# 936         2017-12-01  1630.93
# 953         2017-11-06  1678.79
# ...

# %%
# ordenamos las filas del dataframe por fechas en orden ascendente

# %%
transacciones_nomina_df.sort_values(by='Fecha transacción', inplace=True)
transacciones_nomina_df
# Out:
# <ipython-input-553-b26ae4222500>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transacciones_nomina_df.sort_values(by='Fecha transacción', inplace=True)
#      Fecha transacción  Importe
# 1482        2016-09-05  1533.02
# 1467        2016-10-04  1633.95
# 1428        2016-11-02  1640.70
# 1374        2016-12-07  1640.70
# 1346        2016-12-21  1633.41
# 1340        2016-12-28  1640.70
# 1284        2017-02-02  1640.70
# 1247        2017-03-02  1293.45
# 1209        2017-04-03  1642.52
# 1193        2017-05-02  2178.64
# 1154        2017-06-02  1947.61
# 1115        2017-07-03  1632.61
# 1068        2017-08-03  1623.42
# 1069        2017-08-03  2172.61
# 1004        2017-09-01  1812.12
# 982         2017-10-03  2099.33
# 953         2017-11-06  1678.79
# 936         2017-12-01  1630.93
# ...

# %%
# renombramos columnas

# %%
transacciones_nomina_df.columns = ['FECHA', 'IMPORTE']
transacciones_nomina_df
# Out:
#           FECHA  IMPORTE
# 1482 2016-09-05  1533.02
# 1467 2016-10-04  1633.95
# 1428 2016-11-02  1640.70
# 2016-10-04    1633.95
# 2016-11-02    1640.70
# 2016-12-07    1640.70
# 2016-12-21    1633.41
# 2016-12-28    1640.70
# 2017-02-02    1640.70
# 2017-03-02    1293.45
# 2017-04-03    1642.52
# 2017-05-02    2178.64
# 2017-06-02    1947.61
# 2017-07-03    1632.61
# 2017-08-03    3796.03
# 2017-09-01    1812.12
# 2017-10-03    2099.33
# 2017-11-06    1678.79
# 2017-12-01    1630.93
# 2018-02-01    2451.77
# 2018-03-05    3964.43
# 2018-04-04    1799.26
# 2018-05-04    1799.26
# 2018-06-01    1799.26
# 2018-07-03    1789.39
# 2018-07-26    1882.53
# 2018-08-01    1789.39
# 2018-09-03    1789.39
# 2018-10-02    2515.38
# 2018-11-02    2382.94
# 2018-12-04    1789.39
# 2018-12-21    1882.53
# 2019-02-04    1675.77
# 2019-03-04    1675.77
# 2019-04-03    1675.77
# 2019-04-09    1500.00
# 2019-05-03    3456.76
# 2019-06-04    1675.77
# 2019-10-02    1675.77
# 2019-11-06    1675.77
# 2019-12-04    1600.00
# 2019-12-20    1758.22
# 2020-05-05    2004.95
# ...

# %%
# Plotting Time Series

# %%
from matplotlib import pyplot
pyplot.plot(transacciones_nomina_ser)
pyplot.show()

# %%
# Lesson 03: Data Visualization

# %%
# Time Series Data Visualization with Python
# https://machinelearningmastery.com/time-series-data-visualization-with-python/

# %%
# Time Series Visualization

# %%
# 1. Time Series Line Plot

# %%
from matplotlib import pyplot
transacciones_nomina_ser.plot()
pyplot.show()

# %%
from matplotlib import pyplot
transacciones_nomina_ser.plot(style='.')
pyplot.show()

# %%
from matplotlib import pyplot
transacciones_nomina_ser.plot(style='s')
pyplot.show()

# %%
# para hacer subplots necesito años completos y me quedo con 2017, 2018 y 2019

# %%
transacciones_nomina_17_19_ser=transacciones_nomina_ser.truncate('2017-01-01', '2019-12-31', copy = False)
transacciones_nomina_17_19_ser
# Out:
# FECHA
# 2017-02-02    1640.70
# 2017-03-02    1293.45
# 2017-04-03    1642.52
# 2017-05-02    2178.64
# 2017-06-02    1947.61
# 2017-07-03    1632.61
# 2017-08-03    3796.03
# 2017-09-01    1812.12
# 2017-10-03    2099.33
# 2017-11-06    1678.79
# 2017-12-01    1630.93
# 2018-02-01    2451.77
# 2018-03-05    3964.43
# 2018-04-04    1799.26
# 2018-05-04    1799.26
# 2018-06-01    1799.26
# 2018-07-03    1789.39
# 2018-07-26    1882.53
# 2018-08-01    1789.39
# 2018-09-03    1789.39
# 2018-10-02    2515.38
# 2018-11-02    2382.94
# 2018-12-04    1789.39
# 2018-12-21    1882.53
# 2019-02-04    1675.77
# 2019-03-04    1675.77
# 2019-04-03    1675.77
# 2019-04-09    1500.00
# 2019-05-03    3456.76
# 2019-06-04    1675.77
# 2019-10-02    1675.77
# 2019-11-06    1675.77
# 2019-12-04    1600.00
# 2019-12-20    1758.22
# Name: IMPORTE, dtype: float64

# %%
# repetimos desde aqui el estudio estadistico

# %%
# Lesson 02: Load Time Series Data

# %%
# How to Load and Explore Time Series Data in Python
# https://machinelearningmastery.com/load-explore-time-series-data-python/

# %%
# Descriptive Statistics

# %%
transacciones_nomina_17_19_ser.describe()
# Out:
# count      34.000000
# mean     1981.095588
# std       614.138313
# min      1293.450000
# 25%      1675.770000
# 50%      1789.390000
# 75%      1931.340000
# max      3964.430000
# Name: IMPORTE, dtype: float64

# %%
"""
Tenemos 34 valores de nomina en 36 meses
"""
# Out:
# '\nTenemos 34 valores de nomina en 36 meses\n'

# %%
# Plotting Time Series

# %%
from pandas import read_csv
from matplotlib import pyplot
pyplot.plot(transacciones_nomina_17_19_ser)
pyplot.show()

# %%
# Lesson 03: Data Visualization

# %%
# Time Series Data Visualization with Python
# https://machinelearningmastery.com/time-series-data-visualization-with-python/

# %%
from matplotlib import pyplot
transacciones_nomina_17_19_ser.plot()
pyplot.show()

# %%
from matplotlib import pyplot
transacciones_nomina_17_19_ser.plot(style='.')
pyplot.show()

# %%
from matplotlib import pyplot
transacciones_nomina_17_19_ser.plot(style='s')
pyplot.show()

# %%
transacciones_nomina_17_19_ser
# Out:
# FECHA
# 2017-02-02    1640.70
# 2017-03-02    1293.45
# 2017-04-03    1642.52
# 2017-05-02    2178.64
# 2017-06-02    1947.61
# 2017-07-03    1632.61
# 2017-08-03    3796.03
# 2017-09-01    1812.12
# 2017-10-03    2099.33
# 2017-11-06    1678.79
# 2017-12-01    1630.93
# 2018-02-01    2451.77
# 2018-03-05    3964.43
# 2018-04-04    1799.26
# 2018-05-04    1799.26
# 2018-06-01    1799.26
# 2018-07-03    1789.39
# 2018-07-26    1882.53
# 2018-08-01    1789.39
# 2018-09-03    1789.39
# 2018-10-02    2515.38
# 2018-11-02    2382.94
# 2018-12-04    1789.39
# 2018-12-21    1882.53
# 2019-02-04    1675.77
# 2019-03-04    1675.77
# 2019-04-03    1675.77
# 2019-04-09    1500.00
# 2019-05-03    3456.76
# 2019-06-04    1675.77
# 2019-10-02    1675.77
# 2019-11-06    1675.77
# 2019-12-04    1600.00
# 2019-12-20    1758.22
# Name: IMPORTE, dtype: float64

# %%
# no puedes pintar plots por años porque para eso tienes q rellenar los dias que faltan con ceros

# %%
# 2. Time Series Histogram and Density Plots

# %%
from matplotlib import pyplot
transacciones_nomina_17_19_ser.hist()
pyplot.show()

# %%
transacciones_nomina_17_19_df=DataFrame(transacciones_nomina_17_19_ser)

# %%
transacciones_nomina_17_19_df.describe()
# Out:
#            IMPORTE
# count    34.000000
# mean   1981.095588
# std     614.138313
# min    1293.450000
# 25%    1675.770000
# 50%    1789.390000
# 75%    1931.340000
# max    3964.430000

# %%
"""
La nomina tiene valores entre 1500 eur y 2500 eur y, en la mayor parte de los casos, entre 1500 y 2000 eur.
Los casos en los que la nomina esta entre 3500 y 4000 eur son aquellos en los que se cobraron dos nominas ese dia o algun
outlier.
"""
# Out:
# '\nLa nomina tiene valores entre 1500 eur y 2500 eur y, en la mayor parte de los casos, entre 1500 y 2000 eur.\nLos casos en los que la nomina esta entre 3500 y 4000 eur son aquellos en los que se cobraron dos nominas ese dia o algun\noutlier.\n'

# %%
from matplotlib import pyplot
transacciones_nomina_17_19_ser.plot(kind='kde')
pyplot.show()

# %%
transacciones_nomina_17_19_ser.describe()
# Out:
# count      34.000000
# mean     1981.095588
# std       614.138313
# min      1293.450000
# 25%      1675.770000
# 50%      1789.390000
# 75%      1931.340000
# max      3964.430000
# Name: IMPORTE, dtype: float64

# %%
"""
El diagrama de densidad solo confirman lo que ya vimos en los histogramas.
"""
# Out:
# '\nEl diagrama de densidad solo confirman lo que ya vimos en los histogramas.\n'

# %%
from pandas import DataFrame
from pandas import Grouper
from matplotlib import pyplot

transacciones_nomina_17_19_df.boxplot()
pyplot.show()

# %%
"""
Otra forma de ver lo que ya vimos en el diagrama de densidad.
Vemos que no hay muchos outliers >= Q3 + 1.5*IQR = 1931.64 + 1.5*(1931.34 - 1675.77) = 2314.995
"""
# Out:
# '\nOtra forma de ver lo que ya vimos en el diagrama de densidad.\nVemos que no hay muchos outliers >= Q3 + 1.5*IQR = 1931.64 + 1.5*(1931.34 - 1675.77) = 2314.995\n'

# %%
from pandas import DataFrame
from pandas import Grouper
from matplotlib import pyplot

pyplot.matshow(transacciones_nomina_17_19_df.T, interpolation=None, aspect='auto')
pyplot.show()

# %%
"""
no se pueden sacar conclusiones utiles del mapa de color
"""
# Out:
# '\nno se pueden sacar conclusiones utiles del mapa de color\n'

# %%
# create a scatter plot
from matplotlib import pyplot
from pandas.plotting import lag_plot
lag_plot(transacciones_nomina_17_19_ser)
pyplot.show()

# %%
"""
No hay correlacion entre y(t+1) e y(t)
"""
# Out:
# '\nNo hay correlacion entre y(t+1) e y(t)\n'

# %%
"""
Vamos a hacer lagplots entre y(t+1) y sus 12 lags anteriores hasta y(t-12)
"""
# Out:
# '\nVamos a hacer lagplots entre y(t+1) y sus 12 lags anteriores hasta y(t-12)\n'

# %%
from pandas import DataFrame
from pandas import concat
from matplotlib import pyplot
from pandas.plotting import scatter_matrix
values = DataFrame(transacciones_nomina_17_19_ser.values)
lags = 12
columns = [values]
for i in range(1,(lags + 1)):
	columns.append(values.shift(i))
dataframe = concat(columns, axis=1)
columns = ['t+1']
for i in range(1,(lags + 1)):
	columns.append('t-' + str(i))
dataframe.columns = columns
for i in range(1,(lags + 1)):
	print('t+1 vs t-' + str(i))
	pyplot.scatter(x=dataframe['t+1'].values, y=dataframe['t-'+str(i)].values)
	pyplot.show()
# Out:
# t+1 vs t-1
# t+1 vs t-2
# t+1 vs t-3
# t+1 vs t-4
# t+1 vs t-5
# t+1 vs t-6
# t+1 vs t-7
# t+1 vs t-8
# t+1 vs t-9
# t+1 vs t-10
# t+1 vs t-11
# t+1 vs t-12

# %%
"""
No se parecia correlacion entre y(t+1) y sus 12 lags anteriores.
"""
# Out:
# '\nNo se parecia correlacion entre y(t+1) y sus 12 lags anteriores.\n'

# %%
# 6. Time Series Autocorrelation Plots

# %%
# create an autocorrelation plot
from pandas import read_csv
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(transacciones_nomina_17_19_ser)
pyplot.show()

# %%
"""
Vemos que no hay una correlacion siginicativa entre y(t+1) y sus lags anteriores.
Esta serie temporal no es modelizable.
"""
# Out:
# '\nVemos que no hay una correlacion siginicativa entre y(t+1) y sus lags anteriores.\nEsta serie temporal no es modelizable.\n'

# %%
# a continuacion voy a rellenar con 0s los valores que no tienen fecha y repetir el estudio estadistico

# %%
trans_nomina_filled_17_19_df=transacciones_nomina_17_19_df.copy()
trans_nomina_filled_17_19_df
# Out:
#             IMPORTE
# FECHA
# 2017-02-02  1640.70
# 2017-03-02  1293.45
# 2017-04-03  1642.52
# 2017-05-02  2178.64
# 2017-06-02  1947.61
# 2017-07-03  1632.61
# 2017-08-03  3796.03
# 2017-09-01  1812.12
# 2017-10-03  2099.33
# 2017-11-06  1678.79
# 2017-12-01  1630.93
# 2018-02-01  2451.77
# 2018-03-05  3964.43
# 2018-04-04  1799.26
# 2018-05-04  1799.26
# 2018-06-01  1799.26
# 2018-07-03  1789.39
# 2018-07-26  1882.53
# 2018-08-01  1789.39
# 2018-09-03  1789.39
# 2018-10-02  2515.38
# 2018-11-02  2382.94
# 2018-12-04  1789.39
# 2018-12-21  1882.53
# 2019-02-04  1675.77
# 2019-03-04  1675.77
# 2019-04-03  1675.77
# 2019-04-09  1500.00
# 2019-05-03  3456.76
# 2019-06-04  1675.77
# 2019-10-02  1675.77
# 2019-11-06  1675.77
# 2019-12-04  1600.00
# 2019-12-20  1758.22

# %%
range_of_dates = date_range(start='2017-01-01', end='2019-12-31')
range_of_dates
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10',
#                ...
#                '2019-12-22', '2019-12-23', '2019-12-24', '2019-12-25',
#                '2019-12-26', '2019-12-27', '2019-12-28', '2019-12-29',
#                '2019-12-30', '2019-12-31'],
#               dtype='datetime64[ns]', length=1095, freq='D')

# %%
trans_nomina_filled_17_19_df=\
trans_nomina_filled_17_19_df.reindex(range_of_dates).fillna(0.0).rename_axis('FECHA').reset_index()

# %%
# Lesson 02: Load Time Series Data

# %%
# How to Load and Explore Time Series Data in Python
# https://machinelearningmastery.com/load-explore-time-series-data-python/

# %%
# Load Time Series Data

# %%
trans_nomina_filled_17_19_df
# Out:
#           FECHA  IMPORTE
# 0    2017-01-01      0.0
# 1    2017-01-02      0.0
# 2    2017-01-03      0.0
# 3    2017-01-04      0.0
# 4    2017-01-05      0.0
# ...         ...      ...
# 1090 2019-12-27      0.0
# 1091 2019-12-28      0.0
# 1092 2019-12-29      0.0
# 1093 2019-12-30      0.0
# 1094 2019-12-31      0.0
#
# [1095 rows x 2 columns]

# %%
# Descriptive Statistics

# %%
trans_nomina_filled_17_19_df.describe()
# Out:
#            IMPORTE
# count  1095.000000
# mean     61.513470
# std     359.951559
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max    3964.430000

# %%
trans_nomina_filled_17_19_df=trans_nomina_filled_17_19_df.set_index('FECHA')
trans_nomina_filled_17_19_df
# Out:
#             IMPORTE
# FECHA
# 2017-01-01      0.0
# 2017-01-02      0.0
# 2017-01-03      0.0
# 2017-01-04      0.0
# 2017-01-05      0.0
# ...             ...
# 2019-12-27      0.0
# 2019-12-28      0.0
# 2019-12-29      0.0
# 2019-12-30      0.0
# 2019-12-31      0.0
#
# [1095 rows x 1 columns]

# %%
# Plotting Time Series

# %%
from pandas import read_csv
from matplotlib import pyplot
pyplot.plot(trans_nomina_filled_17_19_df)
pyplot.show()

# %%
# Lesson 03: Data Visualization

# %%
# Time Series Data Visualization with Python
# https://machinelearningmastery.com/time-series-data-visualization-with-python/

# %%
from matplotlib import pyplot
trans_nomina_filled_17_19_df.plot()
pyplot.show()

# %%
from matplotlib import pyplot
trans_nomina_filled_17_19_df.plot(style='.')
pyplot.show()

# %%
from matplotlib import pyplot
trans_nomina_filled_17_19_df.plot(style='s')
pyplot.show()

# %%
trans_nomina_filled_17_19_ser=trans_nomina_filled_17_19_df.T.squeeze()
trans_nomina_filled_17_19_ser
# Out:
# FECHA
# 2017-01-01    0.0
# 2017-01-02    0.0
# 2017-01-03    0.0
# 2017-01-04    0.0
# 2017-01-05    0.0
#              ...
# 2019-12-27    0.0
# 2019-12-28    0.0
# 2019-12-29    0.0
# 2019-12-30    0.0
# 2019-12-31    0.0
# Name: IMPORTE, Length: 1095, dtype: float64

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import Grouper
from matplotlib import pyplot
groups = trans_nomina_filled_17_19_ser.groupby(Grouper(freq='A'))
years = DataFrame()
for name, group in groups:
	years[name.year] = group.values
years.plot(subplots=False, legend=True)
years.plot(subplots=True, legend=True)
years.plot(subplots=True, legend=False)
pyplot.show()

# %%
"""
Podemos ver que los cobros se producen en las mismas fechas y por cantidades parecidas
"""
# Out:
# '\nPodemos ver que los cobros se producen en las mismas fechas y por cantidades parecidas\n'

# %%
position = range(0,6)
color = ['tab:blue','tab:orange','tab:green'] #,'tab:red','tab:purple','tab:brown']

for i,j in zip(position,color):
    years.iloc[:,i].plot(style=j, legend=True)
    pyplot.show()

# %%
"""
aqui se ve muy claramente como los cobros de nomina se producen en los mismos dias a lo largo de un año
"""
# Out:
# '\naqui se ve muy claramente como los cobros de nomina se producen en los mismos dias a lo largo de un año\n'

# %%
# 2. Time Series Histogram and Density Plots

# %%
from matplotlib import pyplot
trans_nomina_filled_17_19_df.hist()
pyplot.show()

# %%
from matplotlib import pyplot
transacciones_nomina_17_19_ser.hist()
pyplot.show()

# %%
"""
De aqui el histograma que vale es el de las transacciones no rellenadas. 
Y vemos que la nomina tiene valores entre 1500 eur y 2500 eur y, en la mayor parte de los casos, entre 1500 y 2000 eur.
Los casos en los que la nomina esta entre 3500 y 4000 eur son aquellos en los que se cobraron dos nominas ese dia o algun
outlier
"""
# Out:
# '\nDe aqui el histograma que vale es el de las transacciones no rellenadas. \nY vemos que la nomina tiene valores entre 1500 eur y 2500 eur y, en la mayor parte de los casos, entre 1500 y 2000 eur.\nLos casos en los que la nomina esta entre 3500 y 4000 eur son aquellos en los que se cobraron dos nominas ese dia o algun\noutlier\n'

# %%
from matplotlib import pyplot
trans_nomina_filled_17_19_df.plot(kind='kde')
pyplot.show()

# %%
from matplotlib import pyplot
transacciones_nomina_17_19_ser.plot(kind='kde')
pyplot.show()

# %%
"""
Los diagramas de densidad solo nos confirman lo que ya vimos en los histogramas.
"""
# Out:
# '\nLos diagramas de densidad solo nos confirman lo que ya vimos en los histogramas.\n'

# %%
# 3. Time Series Box and Whisker Plots by Interval

# %%
from pandas import DataFrame
from pandas import Grouper
from matplotlib import pyplot
groups = trans_nomina_filled_17_19_ser.groupby(Grouper(freq='A'))
years = DataFrame()
for name, group in groups:
	years[name.year] = group.values
years.boxplot()
pyplot.show()

# %%
trans_nomina_filled_17_19_df.describe()
# Out:
#            IMPORTE
# count  1095.000000
# mean     61.513470
# std     359.951559
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max    3964.430000

# %%
"""
El boxplot por años no nos es de mucha utilidad ya que casi todas observaciones son '0' excepto los salarios que los trata
como outliers.
"""
# Out:
# "\nEl boxplot por años no nos es de mucha utilidad ya que casi todas observaciones son '0' excepto los salarios que los trata\ncomo outliers.\n"

# %%
# hagamos el boxplot por meses a lo largo de un año para ver si podemos sacar conclusiones de estacionalidad

# %%
# create a boxplot of monthly data
from pandas import read_csv
from pandas import DataFrame
from pandas import Grouper
from matplotlib import pyplot
from pandas import concat
color = ['blue','orange','green'] #,'red','purple','brown']
times = ['2017', '2018', '2019']
for n,j in zip(times,color):
    one_year = trans_nomina_filled_17_19_ser[n]
    groups = one_year.groupby(Grouper(freq='M'))
    months = concat([DataFrame(x[1].values) for x in groups], axis=1)
    months = DataFrame(months)
    months.columns = range(1,13)
    print('Año:' + n)
    months.boxplot(color=j)
    pyplot.show()
# Out:
# Año:2017
# Año:2018
# Año:2019

# %%
"""
Los boxplots se convierten en series temporales en los que las observaciones de los ingresos de la nomina se toman como
outliers.

No obstante vemos como, en general, las observaciones de los ingresos de la nomina toman valores parecidos.
"""
# Out:
# '\nLos boxplots se convierten en series temporales en los que las observaciones de los ingresos de la nomina se toman como\noutliers.\n\nNo obstante vemos como, en general, las observaciones de los ingresos de la nomina toman valores parecidos.\n'

# %%
# 4. Time Series Heat Maps

# %%
from pandas import DataFrame
from pandas import Grouper
from matplotlib import pyplot
groups = trans_nomina_filled_17_19_ser.groupby(Grouper(freq='A'))
years = DataFrame()
for name, group in groups:
	years[name.year] = group.values
years = years.T
pyplot.matshow(years, interpolation=None, aspect='auto')
pyplot.show()

# %%
"""
Observamos que hay doce rayas brillantes que coinciden muy bien a lo largo de los tres años y corresponden a los dias en que
hubo ingreso de nomina.
"""
# Out:
# '\nObservamos que hay doce rayas brillantes que coinciden muy bien a lo largo de los tres años y corresponden a los dias en que\nhubo ingreso de nomina.\n'

# %%
"""
Pintamos los heatmaps por meses.
"""
# Out:
# '\nPintamos los heatmaps por meses.\n'

# %%
from pandas import read_csv
from pandas import Grouper
from matplotlib import pyplot
from pandas import concat
times = ['2017', '2018', '2019'] #, '2020']
for n in times:
    one_year = trans_nomina_filled_17_19_ser[n]
    groups = one_year.groupby(Grouper(freq='M'))
    months = concat([DataFrame(x[1].values) for x in groups], axis=1)
    months = DataFrame(months)
    months.columns = range(1,13)
    months = months.T
    print('year ' + n)
    pyplot.matshow(months, interpolation=None, aspect='auto')
    pyplot.show()
# Out:
# year 2017
# year 2018
# year 2019

# %%
"""
En los heatmaps se ve muy claramente que cobra la nomina entre el dia 1 y 6 de cada mes.

También tiene pagas extra el 20 de diciembre de 2018 y el 21 de diciembre de 2019.

Y una paga extra el 26 de julio de 2018.
"""
# Out:
# '\nEn los heatmaps se ve muy claramente que cobra la nomina entre el dia 1 y 6 de cada mes.\n\nTambién tiene pagas extra el 20 de diciembre de 2018 y el 21 de diciembre de 2019.\n\nY una paga extra el 26 de julio de 2018.\n'

# %%
# 5. Time Series Lag Scatter Plots

# %%
# create a scatter plot
from matplotlib import pyplot
from pandas.plotting import lag_plot
lag_plot(trans_nomina_filled_17_19_ser)
pyplot.show()

# %%
"""
No hay correlacion entre y(t+1) e y(t)
"""
# Out:
# '\nNo hay correlacion entre y(t+1) e y(t)\n'

# %%
"""
Ahora vamos a hacer lagplots entre y(t+1) y sus 12 lags anteriores hasta y(t-12)
"""
# Out:
# '\nAhora vamos a hacer lagplots entre y(t+1) y sus 12 lags anteriores hasta y(t-12)\n'

# %%
from pandas import DataFrame
from pandas import concat
from matplotlib import pyplot
from pandas.plotting import scatter_matrix
values = DataFrame(trans_nomina_filled_17_19_ser.values)
lags = 12
columns = [values]
for i in range(1,(lags + 1)):
	columns.append(values.shift(i))
dataframe = concat(columns, axis=1)
columns = ['t+1']
for i in range(1,(lags + 1)):
	columns.append('t-' + str(i))
dataframe.columns = columns
for i in range(1,(lags + 1)):
	print('t+1 vs t-' + str(i))
	pyplot.scatter(x=dataframe['t+1'].values, y=dataframe['t-'+str(i)].values)
	pyplot.show()
# Out:
# t+1 vs t-1
# t+1 vs t-2
# t+1 vs t-3
# t+1 vs t-4
# t+1 vs t-5
# t+1 vs t-6
# t+1 vs t-7
# t+1 vs t-8
# t+1 vs t-9
# t+1 vs t-10
# t+1 vs t-11
# t+1 vs t-12

# %%
"""
No se observa correlacion entre y(t+1) y sus dos lags anteriores.
"""
# Out:
# '\nNo se observa correlacion entre y(t+1) y sus dos lags anteriores.\n'

# %%
# 6. Time Series Autocorrelation Plots

# %%
# create an autocorrelation plot
from pandas import read_csv
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(trans_nomina_filled_17_19_ser)
pyplot.show()

# %%
"""
Observamos correlacion significativa baja con 13 de los 1095 lags anteriores.
Pero incluso en estos 13 casos la correlacion es muy baja < 0.33.
Esta serie temporal no es modelizable.
"""
# Out:
# '\nObservamos correlacion significativa baja con 13 de los 1095 lags anteriores.\nPero incluso en estos 13 casos la correlacion es muy baja < 0.33.\nEsta serie temporal no es modelizable.\n'

# %%
# hacemos un dataframe con el dia que pagaron la nomina para ver en que dias se cobra mas frecuentemente la misma

# %%
transacciones_nomina_17_19_df
# Out:
#             IMPORTE
# FECHA
# 2017-02-02  1640.70
# 2017-03-02  1293.45
# 2017-04-03  1642.52
# 2017-05-02  2178.64
# 2017-06-02  1947.61
# 2017-07-03  1632.61
# 2017-08-03  3796.03
# 2017-09-01  1812.12
# 2017-10-03  2099.33
# 2017-11-06  1678.79
# 2017-12-01  1630.93
# 2018-02-01  2451.77
# 2018-03-05  3964.43
# 2018-04-04  1799.26
# 2018-05-04  1799.26
# 2018-06-01  1799.26
# 2018-07-03  1789.39
# 2018-07-26  1882.53
# 2018-08-01  1789.39
# 2018-09-03  1789.39
# 2018-10-02  2515.38
# 2018-11-02  2382.94
# 2018-12-04  1789.39
# 2018-12-21  1882.53
# 2019-02-04  1675.77
# 2019-03-04  1675.77
# 2019-04-03  1675.77
# 2019-04-09  1500.00
# 2019-05-03  3456.76
# 2019-06-04  1675.77
# 2019-10-02  1675.77
# 2019-11-06  1675.77
# 2019-12-04  1600.00
# 2019-12-20  1758.22

# %%
dias_trans_nomina_17_19_df=transacciones_nomina_17_19_df.copy()
dias_trans_nomina_17_19_df
# Out:
#             IMPORTE
# FECHA
# 2017-02-02  1640.70
# 2017-03-02  1293.45
# 2017-04-03  1642.52
# 2017-05-02  2178.64
# 2017-06-02  1947.61
# 2017-07-03  1632.61
# 2017-08-03  3796.03
# 2018-06-01  1799.26 2018-06-01    1
# 2018-07-03  1789.39 2018-07-03    3
# 2018-07-26  1882.53 2018-07-26   26
# 2018-08-01  1789.39 2018-08-01    1
# 2018-09-03  1789.39 2018-09-03    3
# 2018-10-02  2515.38 2018-10-02    2
# 2018-11-02  2382.94 2018-11-02    2
# 2018-12-04  1789.39 2018-12-04    4
# 2018-12-21  1882.53 2018-12-21   21
# 2019-02-04  1675.77 2019-02-04    4
# ...

# %%
# hacemos un drop de IMPORTE Y FECHA para quedarnos solo con DIA

# %%
dias_trans_nomina_17_19_df=dias_trans_nomina_17_19_df.drop(columns=['IMPORTE','FECHA'])
dias_trans_nomina_17_19_df
# Out:
#             DIA
# FECHA
# 2017-02-02    2
# 2017-03-02    2
# 2017-04-03    3
# 2017-05-02    2
# 2017-06-02    2
# 2017-07-03    3
# 2017-08-03    3
# 2017-09-01    1
# 2017-10-03    3
# 2017-11-06    6
# 2017-12-01    1
# 2018-02-01    1
# 2018-03-05    5
# 2018-04-04    4
# 2018-05-04    4
# 2018-06-01    1
# 2018-07-03    3
# 2018-07-26   26
# 2018-08-01    1
# 2018-09-03    3
# 2018-10-02    2
# 2018-11-02    2
# 2018-12-04    4
# 2018-12-21   21
# 2019-02-04    4
# 2019-03-04    4
# 2019-04-03    3
# 2019-04-09    9
# 2019-05-03    3
# 2019-06-04    4
# 2019-10-02    2
# 2019-11-06    6
# 2019-12-04    4
# 2019-12-20   20

# %%
# Lesson 02: Load Time Series Data

# %%
# How to Load and Explore Time Series Data in Python
# https://machinelearningmastery.com/load-explore-time-series-data-python/

# %%
# Descriptive Statistics

# %%
dias_trans_nomina_17_19_df.describe()
# Out:
#              DIA
# count  34.000000
# mean    4.823529
# std     5.828200
# min     1.000000
# 25%     2.000000
# 50%     3.000000
# 75%     4.000000
# max    26.000000

# %%
import statistics
statistics.mode(dias_trans_nomina_17_19_df['DIA'])
# Out:
# 3

# %%
"""
El estudio de las principales magnitudes estadisticas nos arroja conclusiones muy interesantes para establecer reglas de
cuando no te han pagado la nomina:

En 3 años (36 meses) tenemos 34 observaciones luego pueden haber dos meses en los que no se cobro la nomina.

El dia medio de pago de la nomina es el 5 de cada mes (mean = 4.82).

La moda del dia de pago de la nomina es el 3.

El 75% de las observaciones son inferiores al dia 4 de cada mes.

El 68.3% de las observaciones está entre 0 y mean +/- 2*std = (-1, 10.64)

El 95.5% de las observaciones está entre 0 y mean +/- 2*std = (-6.82, 16.46)

El 99.7% de las observaciones está entre 0 y mean +/- 3*std = (-12.64, 22.28)
"""
# Out:
# '\nEl estudio de las principales magnitudes estadisticas nos arroja conclusiones muy interesantes para establecer reglas de\ncuando no te han pagado la nomina:\n\nEn 3 años (36 meses) tenemos 34 observaciones luego pueden haber dos meses en los que no se cobro la nomina.\n\nEl dia medio de pago de la nomina es el 5 de cada mes (mean = 4.82).\n\nLa moda del dia de pago de la nomina es el 3.\n\nEl 75% de las observaciones son inferiores al dia 4 de cada mes.\n\nEl 68.3% de las observaciones está entre 0 y mean +/- 2*std = (-1, 10.64)\n\nEl 95.5% de las observaciones está entre 0 y mean +/- 2*std = (-6.82, 16.46)\n\nEl 99.7% de las observaciones está entre 0 y mean +/- 3*std = (-12.64, 22.28)\n'

# %%
# Plotting Time Series

# %%
from pandas import read_csv
from matplotlib import pyplot
pyplot.plot(dias_trans_nomina_17_19_df)
pyplot.show()

# %%
# Lesson 03: Data Visualization

# %%
# Time Series Data Visualization with Python
# https://machinelearningmastery.com/time-series-data-visualization-with-python/

# %%
# 1. Time Series Line Plot

# %%
from matplotlib import pyplot
dias_trans_nomina_17_19_df.plot()
pyplot.show()

# %%
from matplotlib import pyplot
dias_trans_nomina_17_19_df.plot(style='.')
pyplot.show()

# %%
from matplotlib import pyplot
dias_trans_nomina_17_19_df.plot(style='s')
pyplot.show()

# %%
# 2. Time Series Histogram and Density Plots

# %%
from matplotlib import pyplot
dias_trans_nomina_17_19_df.hist()
pyplot.show()

# %%
dias_trans_nomina_17_19_df.describe()
# Out:
#              DIA
# count  34.000000
# mean    4.823529
# std     5.828200
# min     1.000000
# 25%     2.000000
# 50%     3.000000
# 75%     4.000000
# max    26.000000

# %%
"""
En el histograma vemos como casi siempre pagan entre el dia 1 y el dia 3 de cada mes.
En menor proporcion entre el dia 6 y el 10 de cada mes.
Por ultimo vemos dos pagas extras entre el 20 y el 25 de cada mes.
"""
# Out:
# '\nEn el histograma vemos como casi siempre pagan entre el dia 1 y el dia 3 de cada mes.\nEn menor proporcion entre el dia 6 y el 10 de cada mes.\nPor ultimo vemos dos pagas extras entre el 20 y el 25 de cada mes.\n'

# %%
import statistics
statistics.mode(dias_trans_nomina_17_19_df['DIA'])
# Out:
# 3

# %%
from matplotlib import pyplot
dias_trans_nomina_17_19_df.plot(kind='kde')
pyplot.show()

# %%
"""
El diagrama de densidad solo nos confirma lo que ya hemos descrito en el histograma y en el comentario de los datos estadisticos
de la distribucion.
"""
# Out:
# '\nEl diagrama de densidad solo nos confirma lo que ya hemos descrito en el histograma y en el comentario de los datos estadisticos\nde la distribucion.\n'

# %%
# 3. Time Series Box and Whisker Plots by Interval

# %%
from pandas import DataFrame
from pandas import Grouper
from matplotlib import pyplot

dias_trans_nomina_17_19_df.boxplot()
pyplot.show()

# %%
"""
IQR = 4 - 2 = 2
Q2 = 3
moda = 3
LimSupW = 4 + 1.5*2 = 7
LimInfW = 2 - 1.5*2 = -1
"""
# Out:
# '\nIQR = 4 - 2 = 2\nQ2 = 3\nmoda = 3\nLimSupW = 4 + 1.5*2 = 7\nLimInfW = 2 - 1.5*2 = -1\n'

# %%
dias_trans_nomina_17_19_df.describe()
# Out:
#              DIA
# count  34.000000
# mean    4.823529
# std     5.828200
# min     1.000000
# 25%     2.000000
# 50%     3.000000
# 75%     4.000000
# max    26.000000

# %%
# 4. Time Series Heat Maps
# N/A

# %%
# 5. Time Series Lag Scatter Plots

# %%
# create a scatter plot
from matplotlib import pyplot
from pandas.plotting import lag_plot
lag_plot(dias_trans_nomina_17_19_df)
pyplot.show()

# %%
"""
Con tan pocos datos no hay una clara diagonal y no es posible saber si y(t+1) esta correlado con y(t>)
"""
# Out:
# '\nCon tan pocos datos no hay una clara diagonal y no es posible saber si y(t+1) esta correlado con y(t>)\n'

# %%
"""
Ahora vamos a hacer lagplots entre y(t+1) y sus 12 lags anteriores hasta y(t-12)
"""
# Out:
# '\nAhora vamos a hacer lagplots entre y(t+1) y sus 12 lags anteriores hasta y(t-12)\n'

# %%
from pandas import DataFrame
from pandas import concat
from matplotlib import pyplot
from pandas.plotting import scatter_matrix
values = DataFrame(dias_trans_nomina_17_19_df.values)
lags = 12
columns = [values]
for i in range(1,(lags + 1)):
	columns.append(values.shift(i))
dataframe = concat(columns, axis=1)
columns = ['t+1']
for i in range(1,(lags + 1)):
	columns.append('t-' + str(i))
dataframe.columns = columns
for i in range(1,(lags + 1)):
	print('t+1 vs t-' + str(i))
	pyplot.scatter(x=dataframe['t+1'].values, y=dataframe['t-'+str(i)].values)
	pyplot.show()
# Out:
# t+1 vs t-1
# t+1 vs t-2
# t+1 vs t-3
# t+1 vs t-4
# t+1 vs t-5
# t+1 vs t-6
# t+1 vs t-7
# t+1 vs t-8
# t+1 vs t-9
# t+1 vs t-10
# t+1 vs t-11
# t+1 vs t-12

# %%
"""
los scatter plots entre y(t+1) y sus 12 lags son muy parecidos y no ofrecen correlacion entre ningun lag e y(t+1)
"""
# Out:
# '\nlos scatter plots entre y(t+1) y sus 12 lags son muy parecidos y no ofrecen correlacion entre ningun lag e y(t+1)\n'

# %%
# 6. Time Series Autocorrelation Plots

# %%
# create an autocorrelation plot
from pandas import read_csv
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(dias_trans_nomina_17_19_df)
pyplot.show()

# %%
"""
El grafico de autocorrelacion nos confirma lo que ya vimos en los scatter plots.
No hay correlación significativa entre y(t+1) y ninguno de sus lags anteriores.
Esta serie temporal no es modelizable.
"""
# Out:
# '\nEl grafico de autocorrelacion nos confirma lo que ya vimos en los scatter plots.\nNo hay correlación significativa entre y(t+1) y ninguno de sus lags anteriores.\nEsta serie temporal no es modelizable.\n'

# %%
import statistics
statistics.mode(dias_trans_nomina_17_19_df['DIA'])
# Out:
# 3

# %%
dias_trans_nomina_17_19_df.describe()
# Out:
#              DIA
# count  34.000000
# mean    4.823529
# std     5.828200
# min     1.000000
# 25%     2.000000
# 50%     3.000000
# 75%     4.000000
# max    26.000000

# %%
type(dias_trans_nomina_17_19_df.describe())
# Out:
# pandas.core.frame.DataFrame

# %%
# extraemos el 1er cuartil
quartil1=dias_trans_nomina_17_19_df.describe().loc['25%']['DIA']
quartil1
# Out:
# 2.0

# %%
# extraemos el 3er cuartil
quartil3=dias_trans_nomina_17_19_df.describe().loc['75%']['DIA']
quartil3
# Out:
# 4.0

# %%
lim_inferior = quartil1 - 1.5*(quartil3 - quartil1)
lim_inferior
# Out:
# -1.0

# %%
lim_superior = quartil3
lim_superior
# Out:
# 4.0

# %%
"""
CRITERIOS Q DEBEN CUMPLIRSE PARA DETERMINAR Q SE HA COBRADO NOMINA

ID Categoria: 18.0
(Importe >= 950) == True
limite inferior (25%) Q1 - 1.5*IQR >= FECHA
limite superior (75%) Q3 - dia 4 <= FECHA
"""
# Out:
# '\nCRITERIOS Q DEBEN CUMPLIRSE PARA DETERMINAR Q SE HA COBRADO NOMINA\n\nID Categoria: 18.0\n(Importe >= 950) == True\nlimite inferior (25%) Q1 - 1.5*IQR >= FECHA\nlimite superior (75%) Q3 - dia 4 <= FECHA\n'

# %%
"""
seguramente en pandas se podran sumar y restar fechas luego tengo que conseguir un dataframe con las siguientes caracteristicas
y columnas:

INDEX DIA MES FECHA
"""
# Out:
# '\nseguramente en pandas se podran sumar y restar fechas luego tengo que conseguir un dataframe con las siguientes caracteristicas\ny columnas:\n\nINDEX DIA MES FECHA\n'

# %%
dias_trans_nomina_17_19_df
# Out:
#             DIA
# FECHA
# 2017-02-02    2
# 2017-03-02    2
# 2017-04-03    3
# 2017-05-02    2
# 2017-06-02    2
# 2017-07-03    3
# 2017-08-03    3
# 2017-09-01    1
# 2017-10-03    3
# 2017-11-06    6
# 2017-12-01    1
# 2018-02-01    1
# 2018-03-05    5
# 2018-04-04    4
# 2018-05-04    4
# 2018-06-01    1
# 2018-07-03    3
# 2018-07-26   26
# 2018-08-01    1
# 2018-09-03    3
# 2018-10-02    2
# 2018-11-02    2
# 2018-12-04    4
# 2018-12-21   21
# 2019-02-04    4
# 2019-03-04    4
# 2019-04-03    3
# 2019-04-09    9
# 2019-05-03    3
# 2019-06-04    4
# 2019-10-02    2
# 2019-11-06    6
# 2019-12-04    4
# 2019-12-20   20

# %%
dia_mes_trans_nomina_17_19_df=dias_trans_nomina_17_19_df.copy()
dia_mes_trans_nomina_17_19_df
# Out:
#             DIA
# FECHA
# 2017-02-02    2
# 2017-03-02    2
# 2017-04-03    3
# 2017-05-02    2
# 2017-06-02    2
# 2017-07-03    3
# 2017-08-03    3
# 2017-09-01    1
# 2017-10-03    3
# 2017-11-06    6
# 2017-12-01    1
# 2018-02-01    1
# 2018-03-05    5
# 2018-04-04    4
# 2018-05-04    4
# 2018-06-01    1
# 2018-07-03    3
# 2018-07-26   26
# 2018-08-01    1
# 2018-09-03    3
# 2018-10-02    2
# 2018-11-02    2
# 2018-12-04    4
# 2018-12-21   21
# 2019-02-04    4
# 2019-03-04    4
# 2019-04-03    3
# 2019-04-09    9
# 2019-05-03    3
# 2019-06-04    4
# 2019-10-02    2
# 2019-11-06    6
# 2019-12-04    4
# 2019-12-20   20

# %%
dia_mes_trans_nomina_17_19_df['FECHA']=dia_mes_trans_nomina_17_19_df.index
dia_mes_trans_nomina_17_19_df
# Out:
#             DIA      FECHA
# FECHA
# 2017-02-02    2 2017-02-02
# 2017-03-02    2 2017-03-02
# 2017-04-03    3 2017-04-03
# 2017-05-02    2 2017-05-02
# 2017-06-02    2 2017-06-02
# 2017-07-03    3 2017-07-03
# 2017-08-03    3 2017-08-03
# 2017-09-01    1 2017-09-01
# 2017-10-03    3 2017-10-03
# 2017-11-06    6 2017-11-06
# 2017-12-01    1 2017-12-01
# 2018-02-01    1 2018-02-01
# 2018-03-05    5 2018-03-05
# 2018-04-04    4 2018-04-04
# 2018-05-04    4 2018-05-04
# 2018-06-01    1 2018-06-01
# 2018-11-02 2018-11-02   11    2
# 2018-12-04 2018-12-04   12    4
# 2018-12-21 2018-12-21   12   21
# 2019-02-04 2019-02-04    2    4
# 2019-03-04 2019-03-04    3    4
# 2019-04-03 2019-04-03    4    3
# 2019-04-09 2019-04-09    4    9
# ...

# %%
dia_mes_trans_nomina_17_19_df.describe()
# Out:
#              MES        DIA
# count  34.000000  34.000000
# mean    7.117647   4.823529
# std     3.409121   5.828200
# min     2.000000   1.000000
# 25%     4.000000   2.000000
# 50%     7.000000   3.000000
# 75%    10.000000   4.000000
# max    12.000000  26.000000

# %%
dia_mes_trans_nomina_17_19_df['DIA'].describe()['75%']
# Out:
# 4.0

# %%
datetime.now()
# Out:
# datetime.datetime(2021, 5, 24, 13, 12, 26, 631594)

# %%
datetime.now().month
# Out:
# 5

# %%
datetime.now().day
# Out:
# 24

# %%
transacciones_nomina_2016_2020_df = read_csv("transacciones_nomina_df_2016_2020.csv")

# %%
transacciones_nomina_2016_2020_df.head()
# Out:
#    Unnamed: 0       FECHA  IMPORTE
# 0        1482  2016-09-05  1533.02
# 1        1467  2016-10-04  1633.95
# 2        1428  2016-11-02  1640.70
# 3        1374  2016-12-07  1640.70
# 4        1346  2016-12-21  1633.41

# %%
transacciones_nomina_2016_2020_df.tail()
# Out:
#     Unnamed: 0       FECHA  IMPORTE
# 39         148  2019-12-04  1600.00
# 40         134  2019-12-20  1758.22
# 41         127  2020-05-05  2004.95
# 42          33  2020-07-06  2031.55
# 43          16  2020-07-15  1888.97

# %%
transacciones_nomina_2017_2019_df = \
transacciones_nomina_2016_2020_df[transacciones_nomina_2016_2020_df['FECHA'] <= '2019-12-31']

transacciones_nomina_2017_2019_df.tail()
# Out:
#     Unnamed: 0       FECHA  IMPORTE
# 36         227  2019-06-04  1675.77
# 37         181  2019-10-02  1675.77
# 38         164  2019-11-06  1675.77
# 39         148  2019-12-04  1600.00
# 40         134  2019-12-20  1758.22

# %%
transacciones_nomina_2017_2019_df = \
transacciones_nomina_2017_2019_df[transacciones_nomina_2017_2019_df['FECHA'] >= '2017-01-01']

transacciones_nomina_2017_2019_df.head()
# Out:
#     Unnamed: 0       FECHA  IMPORTE
# 6         1284  2017-02-02  1640.70
# 7         1247  2017-03-02  1293.45
# 8         1209  2017-04-03  1642.52
# 9         1193  2017-05-02  2178.64
# 10        1154  2017-06-02  1947.61

# %%
transacciones_nomina_2017_2019_df
# Out:
#     Unnamed: 0       FECHA  IMPORTE
# 6         1284  2017-02-02  1640.70
# 7         1247  2017-03-02  1293.45
# 8         1209  2017-04-03  1642.52
# 9         1193  2017-05-02  2178.64
# 10        1154  2017-06-02  1947.61
# 11        1115  2017-07-03  1632.61
# 12        1068  2017-08-03  1623.42
# 13        1069  2017-08-03  2172.61
# 14        1004  2017-09-01  1812.12
# 15         982  2017-10-03  2099.33
# 16         953  2017-11-06  1678.79
# 17         936  2017-12-01  1630.93
# 18         906  2018-02-01  2451.77
# 19         856  2018-03-05  3964.43
# 20         798  2018-04-04  1799.26
# 36  2019-06-04  1675.77
# 37  2019-10-02  1675.77
# 38  2019-11-06  1675.77
# 39  2019-12-04  1600.00
# 40  2019-12-20  1758.22

# %%
# agrupamos los valores por FECHA para quitarnos los duplicados
transacciones_nomina_2017_2019_df=transacciones_nomina_2017_2019_df.groupby(transacciones_nomina_2017_2019_df.FECHA).sum()
transacciones_nomina_2017_2019_df
# Out:
#             IMPORTE
# FECHA
# 2017-02-02  1640.70
# 2017-03-02  1293.45
# 2017-04-03  1642.52
# 2017-05-02  2178.64
# 2017-06-02  1947.61
# 2017-07-03  1632.61
# 2017-08-03  3796.03
# 2017-09-01  1812.12
# 2017-10-03  2099.33
# 2017-11-06  1678.79
# 2017-12-01  1630.93
# 2018-02-01  2451.77
# 2018-03-05  3964.43
# 2018-04-04  1799.26
# 2018-05-04  1799.26
# 2018-06-01  1799.26
# 2018-07-03  1789.39
# 2018-07-26  1882.53
# 2018-08-01  1789.39
# 2018-09-03  1789.39
# 2018-10-02  2515.38
# 2018-11-02  2382.94
# 2018-12-04  1789.39
# 2018-12-21  1882.53
# 2019-02-04  1675.77
# 2019-03-04  1675.77
# 2019-04-03  1675.77
# 2019-04-09  1500.00
# 2019-05-03  3456.76
# 2019-06-04  1675.77
# 2019-10-02  1675.77
# 2019-11-06  1675.77
# 2019-12-04  1600.00
# 2019-12-20  1758.22

# %%
transacciones_nomina_2017_2019_df.shape
# Out:
# (34, 1)

# %%
transacciones_nomina_2017_2019_df.index = to_datetime(transacciones_nomina_2017_2019_df.index)

# %%
transacciones_nomina_2017_2019_df
# Out:
#             IMPORTE
# FECHA
# 2017-02-02  1640.70
# 2017-03-02  1293.45
# 2017-04-03  1642.52
# 2017-05-02  2178.64
# 2017-06-02  1947.61
# 2017-07-03  1632.61
# 2017-08-03  3796.03
# 2017-09-01  1812.12
# 2017-10-03  2099.33
# 2017-11-06  1678.79
# 2017-12-01  1630.93
# 2018-02-01  2451.77
# 2018-03-05  3964.43
# 2018-04-04  1799.26
# 2018-05-04  1799.26
# 2018-06-01  1799.26
# 2018-07-03  1789.39
# 2018-07-26  1882.53
# 2018-08-01  1789.39
# 2018-09-03  1789.39
# 2018-10-02  2515.38
# 2018-11-02  2382.94
# 2018-12-04  1789.39
# 2018-12-21  1882.53
# 2019-02-04  1675.77
# 2019-03-04  1675.77
# 2019-04-03  1675.77
# 2019-04-09  1500.00
# 2019-05-03  3456.76
# 2019-06-04  1675.77
# 2019-10-02  1675.77
# 2019-11-06  1675.77
# 2019-12-04  1600.00
# 2019-12-20  1758.22

# %%
dia_mes_trans_nomina_17_19_df = dia_mes_trans_nomina_17_19_df.join(transacciones_nomina_2017_2019_df, how='inner')
dia_mes_trans_nomina_17_19_df
# Out:
#             MES  DIA  IMPORTE
# FECHA
# 2017-02-02    2    2  1640.70
# 2017-03-02    3    2  1293.45
# 2017-04-03    4    3  1642.52
# 2017-05-02    5    2  2178.64
# 2017-06-02    6    2  1947.61
# 2017-07-03    7    3  1632.61
# 2017-08-03    8    3  3796.03
# 2017-09-01    9    1  1812.12
# 2017-10-03   10    3  2099.33
# 2017-11-06   11    6  1678.79
# 2017-12-01   12    1  1630.93
# 2018-02-01    2    1  2451.77
# 2018-03-05    3    5  3964.43
# 2018-04-04    4    4  1799.26
# 2018-05-04    5    4  1799.26
# 2018-06-01    6    1  1799.26
# 2018-07-03    7    3  1789.39
# 2018-07-26    7   26  1882.53
# 2018-08-01    8    1  1789.39
# 2018-09-03    9    3  1789.39
# 2018-10-02   10    2  2515.38
# 2018-11-02   11    2  2382.94
# 2018-12-04   12    4  1789.39
# 2018-12-21   12   21  1882.53
# 2019-02-04    2    4  1675.77
# 2019-03-04    3    4  1675.77
# 2019-04-03    4    3  1675.77
# 2019-04-09    4    9  1500.00
# 2019-05-03    5    3  3456.76
# 2019-06-04    6    4  1675.77
# ...

# %%
dia_mes_trans_nomina_17_19_df.shape
# Out:
# (34, 3)

# %%
# ya tenemos el dataframe preparado sobre el que trabajar

# %%
dia_mes_trans_nomina_17_19_df.describe()
# Out:
#              MES        DIA      IMPORTE
# count  34.000000  34.000000    34.000000
# mean    7.117647   4.823529  1981.095588
# std     3.409121   5.828200   614.138313
# min     2.000000   1.000000  1293.450000
# 25%     4.000000   2.000000  1675.770000
# 50%     7.000000   3.000000  1789.390000
# 75%    10.000000   4.000000  1931.340000
# max    12.000000  26.000000  3964.430000

# %%
dia_mes_trans_nomina_17_19_df.dtypes
# Out:
# MES          int64
# DIA          int64
# IMPORTE    float64
# dtype: object

# %%
#current_date_str='2019-05-24'
current_date_str='2019-07-24'

# %%
current_date_str
# Out:
# '2019-07-24'

# %%
current_date_obj = datetime.strptime(current_date_str, '%Y-%m-%d')

# %%
current_date_obj
# Out:
# datetime.datetime(2019, 7, 24, 0, 0)

# %%
current_date_obj.year
# Out:
# 2019

# %%
current_date_obj.month
# Out:
# 7

# %%
current_date_obj.day
# Out:
# 24

# %%
# ahora tenemos que sacar para DIA: 'Q3' y 'Q1 - 1.5*IQR'
# empezamos por Q3

# %%
q3_dia=dia_mes_trans_nomina_17_19_df.describe()['DIA']['75%']

# %%
q3_dia
# Out:
# 4.0

# %%
q3_date_str = str(current_date_obj.year) + '-' + str(current_date_obj.month) +'-' + str(int(q3_dia))

# %%
q3_date_str
# Out:
# '2019-7-4'

# %%
q3_date_obj = datetime.strptime(q3_date_str, '%Y-%m-%d')

# %%
q3_date_obj
# Out:
# datetime.datetime(2019, 7, 4, 0, 0)

# %%
# ahora sacamos Q1

# %%
q1_dia=dia_mes_trans_nomina_17_19_df.describe()['DIA']['25%']

# %%
q1_dia
# Out:
# 2.0

# %%
if q1_dia <= q3_dia:
    q1_date_str = str(current_date_obj.year) + '-' + str(current_date_obj.month) +'-' + str(int(q1_dia))
else:
    if current_date_obj.month != 1:
        q1_date_str = str(current_date_obj.year) + '-' + str(current_date_obj.month - 1) +'-' + str(int(q1_dia))
    else:
        q1_date_str = str(current_date_obj.year - 1) + '-' + str(current_date_obj.month - 1) +'-' + str(int(q1_dia))

# %%
q1_date_str
# Out:
# '2019-7-2'

# %%
q1_date_obj = datetime.strptime(q1_date_str, '%Y-%m-%d')

# %%
q1_date_obj
# Out:
# datetime.datetime(2019, 7, 2, 0, 0)

# %%
iqr_obj = q3_date_obj - q1_date_obj

# %%
iqr_obj
# Out:
# datetime.timedelta(days=2)

# %%
1.5*iqr_obj
# Out:
# datetime.timedelta(days=3)

# %%
limInf_obj = q1_date_obj - 1.5*iqr_obj

# %%
limInf_obj
# Out:
# datetime.datetime(2019, 6, 29, 0, 0)

# %%
from datetime import timedelta, date
limSup_obj = q3_date_obj + timedelta(days=1)

# %%
limSup_obj
# Out:
# datetime.datetime(2019, 7, 5, 0, 0)

# %%
from datetime import timedelta, date

cobrado = False

for d in  range(int((limSup_obj - limInf_obj).days)):    
    fecha = str((limInf_obj + timedelta(d)).year) + '-' + str((limInf_obj + timedelta(d)).month) + '-' + \
    str((limInf_obj + timedelta(d)).day)
    print(fecha)
    if (limInf_obj + timedelta(d)) in dia_mes_trans_nomina_17_19_df.index:
        cobrado = True
        print ('El usuario cobró una nómina de ' + \
               str(dia_mes_trans_nomina_17_19_df['IMPORTE'][str(limInf_obj + timedelta(d))[:10]]) + \
               ' eur el día ' + str(limInf_obj + timedelta(d))[:10])

if not(cobrado):
    fecha = str(q3_date_obj.year) + '-' + str(q3_date_obj.month) + '-' + str(q3_date_obj.day)
    print(fecha + ': El usuario aún no ha cobrado la nómina. Hay que avisarle')
# Out:
# 2019-6-29
# 2019-6-30
# 2019-7-1
# 2019-7-2
# 2019-7-3
# 2019-7-4
# 2019-7-4: El usuario aún no ha cobrado la nómina. Hay que avisarle

# %%
"""
Tendras que crearte un script que del dataframe anterior:
1 - Saque el Q3
2 - Compruebe si FECHA_ACTUAL == Q3 + 1
3 - Chequee en el dataframe si hay fila con:
3.1 - 'ID Categoría' == 18.0
3.2 - 'Importe' >= 950.00
3.3 - FECHA en intervalo (Q1 - 1.5*IQR, Q3)
4 - if (3.1 and 3.2 and 3.3) == True: !genero_aviso
        else genero_aviso
"""
# Out:
# "\nTendras que crearte un script que del dataframe anterior:\n1 - Saque el Q3 y Q3(MES_ACTUAL)\n2 - Compruebe si FECHA_ACTUAL == Q3(MES_ACTUAL) - 1\n3 - Chequee en el dataframe si hay fila con:\n3.1 - 'ID Categoría' == 18.0\n3.2 - 'Importe' >= 950.00\n3.3 - FECHA en intervalo (Q1(MES_ACTUAL) - 1.5*IQR, Q3(MES_ACTUAL))\n4 - if (3.1 and 3.2 and 3.3) == True: !genero_aviso\n        else genero_aviso\n"

# %%
# POR AQUI TE QUEDAS PARA SACARTE EN PYTHON 'FECHA_ACTUAL' EN FORMATO AÑO-MES-DIA

# %%
"""
seguramente en pandas se podran sumar y restar fechas luego tengo que conseguir un dataframe con las siguientes caracteristicas
y columnas:

INDEX FECHA MES DIA
"""
# Out:
# '\nseguramente en pandas se podran sumar y restar fechas luego tengo que conseguir un dataframe con las siguientes caracteristicas\ny columnas:\n\nINDEX FECHA MES DIA\n'
